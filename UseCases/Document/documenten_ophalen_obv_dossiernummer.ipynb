# %% [markdown]
# <a href="https://colab.research.google.com/github/davidvlaminck/AWVGeneric/blob/master/UseCases/Document/documenten_ophalen_obv_dossiernummer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Documenten ophalen op basis van dossiernummer
#
# Download documenten gelinkt aan een specifiek **dossiernunmmer**.
#
# Filter bijkomend op:
# - **document type** *\**
# - **toezichthouder** *\**
# - **provincies** *\**
#
# *\** optioneel
#
# Achterliggend wordt gebruik gemaakt van de [EM-Infra API](https://apps.mow.vlaanderen.be/eminfra/core/swagger-ui/).
#
# Lanceer via de play-knop ![image.png](data:image/png;base64,...)
# aan de linkerzijde achtereenvolgens ieder blokje code.
#
# De eerste blokjes code dienen om alles te initialiseren. Nadien vragen we je de parameters in te vullen en het eigenlijke script te starten.

# %%
import os, shutil
import sys
if os.path.exists('AWVGeneric'):
  shutil.rmtree('AWVGeneric')
# !git clone https://github.com/davidvlaminck/AWVGeneric.git
sys.path.insert(0, '/content/AWVGeneric')  # adds the Python files from the GitHub repo to the sys-path.
sys.path.insert(0, '/content/AWVGeneric/UseCases/Document')  # adds the Python files from the GitHub repo to the sys-path.

import tempfile
from datetime import datetime
from functions import download_documents
import pandas as pd
import re
from google.colab import files

from API.eminfra.EMInfraClient import EMInfraClient
from API.eminfra.EMInfraDomain import DocumentCategorieEnum, ProvincieEnum
from pathlib import Path
from API.Enums import AuthType, Environment
from Generic.ExcelModifier import ExcelModifier

from IPython.display import display
import ipywidgets as widgets
# Out:
# Cloning into 'AWVGeneric'...
# remote: Enumerating objects: 4583, done.
# remote: Counting objects: 100% (1017/1017), done.
# remote: Compressing objects: 100% (460/460), done.
# remote: Total 4583 (delta 665), reused 606 (delta 557), pack-reused 3566 (from 2)
# Receiving objects: 100% (4583/4583), 2.25 MiB | 6.69 MiB/s, done.
# Resolving deltas: 100% (3078/3078), done.

# %% [markdown]
# Lanceer de code via de play-knop en pas onderstaand de parameters aan naar eigen keuze.

# %%
# edelta_dossiernummer
widget_dossiernummer = widgets.Text(value='VWT/DVM/2023/3')
print("Dossiernummer:")
display(widget_dossiernummer)

# document categorie
widget_documentcategorie = widgets.SelectMultiple(
    options=[(item.value, item) for item in DocumentCategorieEnum],
    value=[],
    disabled=False
)
print("\n")
print("Selecteer één of meerdere document categoriën (houd SHIFT ingedrukt om meerdere te selecteren):")
display(widget_documentcategorie)

# toezichter
widget_toezichter = widgets.Text(value='Stefan Missotten')
print("\n")
print("Vul de naam (voornaam familienaam) van een toezichter in:")
print("Via de EM-Infra toepassing kunt u controleren of de toezichter bestaat. https://apps.mow.vlaanderen.be/eminfra/admin/gebruikers")
display(widget_toezichter)

# provincie
widget_provincie = widgets.SelectMultiple(
    options=[(item.value, item) for item in ProvincieEnum],
    value=[],
    rows=6,
    disabled=False
)
print("\n")
print("Selecteer één of meerdere provincies (houd SHIFT ingedrukt om meerdere te selecteren):")
display(widget_provincie)
# Out:
# Dossiernummer:
# Text(value='VWT/DVM/2023/3')
# Selecteer één of meerdere document categoriën (houd SHIFT ingedrukt om meerdere te selecteren):
# SelectMultiple(options=(('AANGEBODEN_SERVICES', <DocumentCategorieEnum.AANGEBODEN_SERVICES: 'AANGEBODEN_SERVIC…
# Vul de naam (voornaam familienaam) van een toezichter in:
# Via de EM-Infra toepassing kunt u controleren of de toezichter bestaat. https://apps.mow.vlaanderen.be/eminfra/admin/gebruikers
# Text(value='Stefan Missotten')
# Selecteer één of meerdere provincies (houd SHIFT ingedrukt om meerdere te selecteren):
# SelectMultiple(options=(('antwerpen', <ProvincieEnum.ANTWERPEN: 'antwerpen'>), ('west-vlaanderen', <ProvincieE…

# %% [markdown]
# Controleer de gekozen parameters

# %%
# edelta_dossiernummer
edelta_dossiernummer = widget_dossiernummer.value
print(f'Dossiernummer:\t\t\t\t{edelta_dossiernummer}')

# document categorie
document_categorien = [item for item in widget_documentcategorie.value]
print(f'Document categorie/categoriën:\t\t{[item.value for item in document_categorien]}')

# toezichter
toezichter = widget_toezichter.value
print(f'Toezichter:\t\t\t\t{toezichter}')

# provincie
provincie = [item for item in widget_provincie.value]
print(f'Provincie(s):\t\t\t\t{[item.value for item in provincie]}')
# Out:
# Dossiernummer:				VWT/DVM/2023/3
# Document categorie/categoriën:		['KEURINGSVERSLAG']
# Toezichter:				Stefan Missotten
# Provincie(s):				['vlaams-brabant']

# %% [markdown]
# Haal een cookie op volgens [deze instructies](https://sites.google.com/mow.vlaanderen.be/em-infra/afspraken-conventies/awv-cookie-ophalen):

# %%
#cookie
widget_cookie = widgets.Text(
    value='',
    placeholder='<vul hier je persoonlijke cookie in>',
    description='Cookie:',)
print("Vul de cookie in:")
display(widget_cookie)
# Out:
# Vul de cookie in:
# Text(value='', description='Cookie:', placeholder='<vul hier je persoonlijke cookie in>')

# %%
# cookie
cookie = widget_cookie.value
eminfra_client = EMInfraClient(cookie=cookie, auth_type=AuthType.COOKIE, env=Environment.PRD)
print(f"Uw persoonlijke cookie is: {cookie}")
# Out:
# Uw persoonlijke cookie is: 086acd7d756e4f348f001effca776dae

# %% [markdown]
# Lanceer de functie om alle documenten te downloaden. Nadat alle documenten gedownload zijn, worden deze gezipt en wordt de .zip-file automatisch gedownload.
#
# Afhankelijk van de gekozen parameters krijgt u meer/minder bestanden en duurt dit langer.

# %%
output_zip = download_documents(client=eminfra_client, edelta_dossiernummer=edelta_dossiernummer,
                    document_categorie=document_categorien, provincie=provincie, toezichter=toezichter)
# Out:
# Ophalen van alle documenten die voldoen aan volgende criteria:	Dossiernummer: VWT/DVM/2023/3	Document categorie: ['KEURINGSVERSLAG']	Toezichter: Stefan Missotten	Provincie: ['vlaams-brabant']
# Downloading documents...
# Processed 0 assets in 0.27 seconds
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A10X12.1__A10P12.2.Z.K__A10P12.2.Z.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A2X72.4__A2P72.4.K__A2P72.4.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A1X4.4__A1P4.4.Z.K' is created or already exists.
# Processed 160 assets in 122.03 seconds
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A10X8.2__A10P8.2.K__A10P8.2.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A2X69.0__A2P69.0.K__A2P69.0.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A2X82.4__A2N82.4.K__A2N82.4.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A10X6.0__A10P6.0.Z.K' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A10X12.1__A10P12.2.Z.K' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A10X0.2__A10P0.2.K__A10P0.2.K.LSDeel' is created or already exists.
# Processed 170 assets in 130.19 seconds
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A10X6.7__A10P6.7.K' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A3X15.7__A3P15.7.K__A3P15.7.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A3X25.8__A3N25.8.K__A3N25.8.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/R0X19.4__R0P19.35.K__R0P19.4.LS' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A8X1.0__A8N1.0.K' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A10X0.2__A10P0.2.K' is created or already exists.
# Processed 180 assets in 140.23 seconds
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A12X13.2__A12N13.2.K__A12N13.2.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A2X71.9__A2P72.25.Z.K__A2P72.25.Z.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A1X3.4__A1P3.4.K__A1P3.4.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A2X71.0__A2P71.0.Z.K__A2P71.0.Z.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A1X3.4__A1P3.4.Z.K__A1P3.4.Z.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A3X9.7__A3N9.7.K__A3N9.7.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A3X17.4__A3N17.4.K__A3N17.4.K.LSDeel' is created or already exists.
# Processed 190 assets in 147.10 seconds
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A2X80.9__A2P80.9.K__A2P80.9.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A10X12.1__A10P12.2.Z.K__A10P12.2.Z.K.LS' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A10X5.2__A10N5.2.K__A10N5.2.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A2X80.8__A2P80.8.K__A2P80.8.K.LSDeel' is created or already exists.
# Processed 200 assets in 157.40 seconds
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A2X68.4__A2N68.4.K__A2N68.4.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A201X2.0__A201P2.0.K__A201P2.0.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A3X12.9__A3P12.9.K__A3P12.9.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A2X74.6__A2P74.6.K__A2P74.6.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A1X1.3__A1N1.3.K' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A1X6.4__A1P6.2.Z.K__A1P6.2.Z.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A2X69.0__A2P69.0.K' is created or already exists.
# Processed 210 assets in 164.69 seconds
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A10X8.2__A10P8.2.K' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A1X8.8__A1N8.8.K__A1N8.8.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A4X6.3__A4N6.2.Z.K__A4N6.2.Z.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/R0X50.0__R0P50.0.K__R0P50.0.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/R0X28.4__R0P28.4.K__R0P28.4.K.LSDeel' is created or already exists.
# Processed 220 assets in 172.50 seconds
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A3X14.2__A3N14.2.K__A3N14.2.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A1X4.4__A1N4.4.K__A1N4.4.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/R0X32.0__R0N32.0.K__R0N32.0.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A3X7.9__A3P7.9.K__A3P7.9.K.LSDeel' is created or already exists.
# Directory '/tmp/tmplvhqic_m/Vlaams-Brabant/Missotten_Stefan/_geen_bestanden_beschikbaar/A2X76.7__A2P76.7.K__A2P76.7.K.LSDeel' is created or already exists.
# Folder /tmp/tmplvhqic_m has been zipped to /root/Downloads/Results/documenten_VWT_DVM_2023_3.

# %%
files.download(f'{output_zip}.zip')

# %%
from google.colab import drive
drive.mount('/content/drive')
